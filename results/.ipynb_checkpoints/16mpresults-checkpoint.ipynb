# %%
import pandas as pd

# %%
results = pd.read_csv("16mpresults.csv")

# %%
results
# Out:
#            model                                              image  \
# 0    extra_large  /home/p01e/p01e_git/data/16mp_20240825/home/la...
# 1          large  /home/p01e/p01e_git/data/16mp_20240825/home/la...
# 2         medium  /home/p01e/p01e_git/data/16mp_20240825/home/la...
# 3          small  /home/p01e/p01e_git/data/16mp_20240825/home/la...
# 4           nano  /home/p01e/p01e_git/data/16mp_20240825/home/la...
# ..           ...                                                ...
# 200  extra_large  /home/p01e/p01e_git/data/16mp_20240825/home/la...
# 201        large  /home/p01e/p01e_git/data/16mp_20240825/home/la...
# 202       medium  /home/p01e/p01e_git/data/16mp_20240825/home/la...
# 203        small  /home/p01e/p01e_git/data/16mp_20240825/home/la...
# 204         nano  /home/p01e/p01e_git/data/16mp_20240825/home/la...
#
#      resolution  detections  average confidence
# 0            16          26            0.450609
# 1            16          38            0.430799
# 2            16          37            0.428321
# 3            16          45            0.424949
# 4            16          41            0.402878
# ..          ...         ...                 ...
# 200          16          35            0.421322
# 201          16          41            0.393595
# 202          16          46            0.410051
# 203          16          49            0.418389
# 204          16          32            0.408463
#
# [205 rows x 5 columns]

# %%
results.boxplot(column='average confidence', by='model')
# Out:
# <Axes: title={'center': 'average confidence'}, xlabel='model'>

# %%
results.hist(column='detections')
# Out:
# array([[<Axes: title={'center': 'detections'}>]], dtype=object)

# %%
results.hist('average confidence')
# Out:
# array([[<Axes: title={'center': 'average confidence'}>]], dtype=object)

# %%
hist(results['detections'])
