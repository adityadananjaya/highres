# %%
import pandas as pd

# %%
results = pd.read_csv("64mpresults.csv")

# %%
results
# Out:
#            model                                              image  \
# 0    extra_large  /home/p01e/64mp_20240825/home/lachlan/django-c...
# 1          large  /home/p01e/64mp_20240825/home/lachlan/django-c...
# 2         medium  /home/p01e/64mp_20240825/home/lachlan/django-c...
# 3          small  /home/p01e/64mp_20240825/home/lachlan/django-c...
# 4           nano  /home/p01e/64mp_20240825/home/lachlan/django-c...
# ..           ...                                                ...
# 185  extra_large  /home/p01e/64mp_20240825/home/lachlan/django-c...
# 186        large  /home/p01e/64mp_20240825/home/lachlan/django-c...
# 187       medium  /home/p01e/64mp_20240825/home/lachlan/django-c...
# 188        small  /home/p01e/64mp_20240825/home/lachlan/django-c...
# 189         nano  /home/p01e/64mp_20240825/home/lachlan/django-c...
#
#      resolution  detections  average confidence
# 0            64          61            0.478362
# 1            64          66            0.470326
# 2            64          50            0.428764
# 3            64          37            0.403945
# 4            64          31            0.380805
# ..          ...         ...                 ...
# 185          64          41            0.476704
# 186          64          44            0.424621
# 187          64          34            0.413759
# 188          64          12            0.429008
# 189          64          13            0.313643
#
# [190 rows x 5 columns]

# %%
results.boxplot(column='average confidence', by='model')
# Out:
# <Axes: title={'center': 'average confidence'}, xlabel='model'>

# %%
results.hist(column='detections')
# Out:
# array([[<Axes: title={'center': 'detections'}>]], dtype=object)

# %%
results.hist('average confidence')
# Out:
# array([[<Axes: title={'center': 'average confidence'}>]], dtype=object)

# %%
hist(results['detections'])
